# %%
import pandas as pd
import numpy as np

# %%
df_orig = pd.read_csv("../data/OrigWithClusters.csv")
df_test = pd.read_csv("../data/recommend.csv")

# %%
df_orig
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28357       82447               mack 10                10 million ways
# 28358       82448                m.o.p.  ante up (robbin hoodz theory)
# 28359       82449                  nine                  whutcha want?
# 28360       82450            will smith                         switch
# 28361       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
## Creating seperate dataframes for first 5 cluster and then displaying a sample of 5 songs per cluster to analyze the clusters

Cluster_Zero = df_orig[df_orig["Cluster_Labels"] == 0]
Cluster_One = df_orig[df_orig["Cluster_Labels"] == 1]
Cluster_Two = df_orig[df_orig["Cluster_Labels"] == 2]
Cluster_Three = df_orig[df_orig["Cluster_Labels"] == 3]
Cluster_Four = df_orig[df_orig["Cluster_Labels"] == 4]

# %%
Cluster_Zero.sample(5)
# Out:
#        Unnamed: 0      artist_name                track_name  release_date  \
# 21059       63570      jimmy cliff            struggling man          1973
# 11488       34793  miranda lambert                  kerosene          2005
# 13275       42289      chuck berry             ramblin' rose          1967
# 22955       68915             ub40  if you ever have forever          2013
# 21170       63866   the ethiopians                i love jah          1977
#
#          genre                                             lyrics  len  \
# 21059   reggae  right live struggle survive fight stay alive s...   46
# 11488  country  wait cause yesterday start smoke cigarettes gu...   63
# 13275    blues  ramble ramble ramble know wild windblown grow ...   27
# 22955   reggae  climb mountains run stand live moment future p...   38
# 21170   reggae  thank praise unto high praise thank praise unt...   41
#
#          dating  violence  world/life  ...   obscene     music  \
# ...

# %%
Cluster_One.sample(5)
# Out:
#        Unnamed: 0        artist_name                             track_name  \
# 15410       49385           morphine                               my brain
# 21031       63473       dennis brown                      change your style
# 5581        16052       fall out boy  this ain't a scene, it's an arms race
# 12016       37233         mark wills                     nineteen somethin'
# 2099         6234  the modern lovers                            she cracked
#
#        release_date    genre  \
# 15410          2000    blues
# 21031          1971   reggae
# 5581           2007      pop
# 12016          2013  country
# 2099           1976      pop
#
#                                                   lyrics  len    dating  \
# 15410  brain tune brain tune know tune brain go brain...   23  0.002770
# 21031  hooligans hooligans stop change hooligan style...   82  0.000907
# 5581   arm dealer fit weapons form word care win long...  129  0.000634
# ...

# %%
Cluster_Two.sample(5)
# Out:
#        Unnamed: 0       artist_name                           track_name  \
# 15229       48733  widespread panic                          radio child
# 11634       35366  carrie underwood              do you hear what i hear
# 857          2271         sam cooke  if i had a hammer (the hammer song)
# 16300       51995    albert collins            bring your fine self home
# 2352         7045      bonnie tyler            if i sing you a love song
#
#        release_date    genre  \
# 15229          1996    blues
# 11634          2007  country
# 857            1964      pop
# 16300          2011    blues
# 2352           1978      pop
#
#                                                   lyrics  len    dating  \
# 15229  radio child quicktosmile precious baby search ...   79  0.060184
# 11634  say night wind little little dance night tail ...   73  0.000810
# 857    hammer hammer morning hammer even land hammer ...   80  0.001012
# ...

# %%
Cluster_Three.sample(5)
# Out:
#        Unnamed: 0    artist_name        track_name  release_date    genre  \
# 12654       40205  the cadillacs              zoom          1957    blues
# 22680       68026         k'naan             abc's          2009   reggae
# 13538       43304     humble pie  old time feelin'          1972    blues
# 11472       34703        alabama        keepin' up          2005  country
# 15102       48267     carey bell  carey bell rocks          1994    blues
#
#                                                   lyrics  len    dating  \
# 12654  damn motherfuckin pills feelin freaky shit pil...  143  0.000763
# 22680  bundle style cold glow like guy bald flow voca...  173  0.000548
# 13538  takin time hangin days feel like wanna feel ri...   39  0.001462
# 11472  goin moon cause goin early comin soon hand clo...   92  0.000797
# 15102  witness strength street knowledge straight out...  186  0.000511
#
#        violence  world/life  ...   obscene     music  movement/places  \
# ...

# %%
Cluster_Four.sample(5)
# Out:
#        Unnamed: 0          artist_name             track_name  release_date  \
# 19338       59632          diana krall  all or nothing at all          1997
# 17239       54643   nat king cole trio   a portrait of jennie          1954
# 11136       33296           john hiatt  crossing muddy waters          2000
# 6186        17876  of monsters and men     king and lionheart          2012
# 22752       68245         bitty mclean                  games          2009
#
#          genre                                             lyrics  len  \
# 19338     jazz  half appeal heart yield inbetween begin lips c...   46
# 17239     jazz  portrait precious masterpiece famous portrait ...   24
# 11136  country  baby go know morning like shoot hollow leave w...  110
# 6186       pop  take worry problems aside think teach winter n...   39
# 22752   reggae  hear voice talk feel heart share fault underst...   40
#
#          dating  violence  world/life  ...   obscene     music  \
# ...

# %%
df_test
# Out:
#    Unnamed: 0               artist_name            track_name  release_date  \
# 0       76885                  godsmack                immune          1998
# 1       65394              dennis brown         second chance          1993
# 2       10980          the black crowes           sister luck          1990
# 3         842           jerry lee lewis   your cheating heart          1960
# 4        2764                 paul anka              eso beso          1966
# 5       54425              noro morales              silencio          1952
# 6       77225  rage against the machine      pistol grip pump          2000
# 7       42962                     taste       railway and gun          1970
# 8       28825              randy travis  messin' with my mind          1986
# 9       16881                  paramore           playing god          2009
#
#      genre                                             lyrics  len    dating  \
# ...

# %%
df_test[df_test["Cluster_Labels"] == 1]
# Out:
#    Unnamed: 0       artist_name   track_name  release_date genre  \
# 2       10980  the black crowes  sister luck          1990   pop
# 5       54425      noro morales     silencio          1952  jazz
# 9       16881          paramore  playing god          2009   pop
#
#                                               lyrics  len    dating  violence  \
# 2  worry sick eye hurt rest head life outside gir...   54  0.001120  0.482490
# 5  fear dark fear thunder fear silence spirit dea...   57  0.001462  0.487965
# 9  decisions precision maybe want change simply a...   91  0.000711  0.543658
#
#    world/life  ...     music  movement/places  light/visual perceptions  \
# 2    0.001120  ...  0.001120         0.001120                  0.078222
# 5    0.140561  ...  0.001462         0.001462                  0.001462
# 9    0.114697  ...  0.000711         0.000711                  0.000711
#
#    family/spiritual  like/girls   sadness  feelings     topic       age  \
# ...

# %%
df_test[df_test["Cluster_Labels"] == 4]
# Out:
#    Unnamed: 0      artist_name           track_name  release_date  genre  \
# 3         842  jerry lee lewis  your cheating heart          1960    pop
# 7       42962            taste      railway and gun          1970  blues
#
#                                               lyrics  len    dating  violence  \
# 3  cheat heart weep sleep sleep come night cheat ...   25  0.204740  0.002506
# 7  railway leave time choose tell tell lose throw...   37  0.051874  0.001645
#
#    world/life  ...     music  movement/places  light/visual perceptions  \
# 3    0.002506  ...  0.002506         0.002506                  0.002506
# 7    0.001645  ...  0.001645         0.001645                  0.001645
#
#    family/spiritual  like/girls   sadness  feelings    topic       age  \
# 3          0.002506    0.002506  0.474607  0.002506  sadness  0.857143
# 7          0.001645    0.001645  0.314594  0.001645  sadness  0.714286
#
#    Cluster_Labels
# 3               4
# 7               4
#
# ...

# %%
df_test[df_test["Cluster_Labels"] == 7]
# Out:
#    Unnamed: 0   artist_name            track_name  release_date    genre  \
# 1       65394  dennis brown         second chance          1993   reggae
# 8       28825  randy travis  messin' with my mind          1986  country
#
#                                               lyrics  len    dating  violence  \
# 1  maybe maybe treat good feel second best girl s...   43  0.001224  0.029943
# 8  say thing care hang long ahead leave start mes...   41  0.001504  0.001504
#
#    world/life  ...     music  movement/places  light/visual perceptions  \
# 1    0.001224  ...  0.001224         0.001224                  0.001224
# 8    0.132148  ...  0.001504         0.001504                  0.001504
#
#    family/spiritual  like/girls   sadness  feelings       topic       age  \
# 1          0.001224    0.056842  0.001224  0.062092  night/time  0.385714
# 8          0.001504    0.001504  0.001504  0.001504  night/time  0.485714
#
#    Cluster_Labels
# 1               7
# 8               7
#
# ...
